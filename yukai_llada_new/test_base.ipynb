# %%
import os
import torch
import json

# folder_kv_base = '../yukai_llada/sims_kv'
# filename = 'batch_0_v_previous.pt'

# path_file_kv = os.path.join(folder_kv_base, filename)
# matrix_sim_step_layer_token = torch.load(path_file_kv)

filename_allinone = 'all_in_one_diff_32_64_4_abs_per_block_p_0326.json'
with open(filename_allinone, 'r') as file:
    content = json.load(file)
# end

# %%
content['batch_0_k_previous.pt'][31]
# Out:
# {'filename': 'batch_0_k_previous.pt',
#  'block': 1,
#  'step': 15,
#  'idx': [7,
#   47,
#   43,
#   41,
#   30,
#   22,
#   37,
#   38,
#   46,
#   11,
#   8,
#   9,
#   27,
#   17,
#   2,
#   13,
#   45,
#   26,
#   28,
#   25,
#   0,
#   6,
#   24,
#   5,
#   23,
#   20,
#   31,
#   4,
#   3,
#   14,
#   32,
#   34,
#   29,
#   40,
#   42,
#   19,
#   33,
#   35,
#   39,
#   15,
#   1,
#   44,
#   21,
#   16,
#   18,
#   12,
#   10,
#   36],
#  'value_raw': [0.007363073527812958,
#   0.004487012047320604,
#   0.011995305307209492,
#   0.006064595188945532,
#   0.006097127683460712,
#   0.006882946006953716,
#   0.007241546176373959,
#   0.11215483397245407,
#   0.02476884052157402,
#   0.02214190363883972,
#   0.003148098010569811,
#   0.0281353946775198,
#   0.0032975156791508198,
#   0.010790393687784672,
#   0.00570739945396781,
#   0.004557221662253141,
#   0.00349589716643095,
#   0.012798008508980274,
#   0.003377634333446622,
#   0.004954982083290815,
#   0.006279510911554098,
#   0.0036740058567374945,
#   0.06592148542404175,
#   0.0063982936553657055,
#   0.007199867162853479,
#   0.008406983688473701,
#   0.008905072696506977,
#   0.01381730381399393,
#   0.0087960883975029,
#   0.0052002668380737305,
#   0.07166030257940292,
#   0.006116896867752075,
#   0.005538028199225664,
#   0.00489903474226594,
#   0.005486947949975729,
#   0.004793290514498949,
#   0.0027154774870723486,
#   0.06431891024112701,
#   0.05045253783464432,
#   0.004659542813897133,
#   0.005167052149772644,
#   0.0971815437078476,
#   0.0050738113932311535,
#   0.09828995168209076,
#   0.0043662176467478275,
#   0.009983700700104237,
#   0.04417455196380615,
#   0.10556291043758392]}
