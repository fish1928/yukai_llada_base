# %%
import torch

mask = torch.arange(3).view(1,3).expand(2,3) > 1
print(mask)
index_column, index_row = torch.where(mask)
print(index_row.reshape(2,-1))
# Out:
# tensor([[False, False,  True],
#         [False, False,  True]])
# tensor([[2],
#         [2]])
