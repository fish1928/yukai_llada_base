# %%
import os
import datasets
from datasets import load_dataset

# %%
print("HF_HOME =", os.getenv("HF_HOME"))
print("HF_HUB_CACHE =", os.getenv("HF_HUB_CACHE"))
print("HF_DATASETS_CACHE =", os.getenv("HF_DATASETS_CACHE"))
print("datasets.config.HF_DATASETS_CACHE =", datasets.config.HF_DATASETS_CACHE)
print("datasets.config.HF_CACHE_HOME =", datasets.config.HF_CACHE_HOME)
# Out:
# HF_HOME = None
# HF_HUB_CACHE = /home/exx/hf_hub_cache
# HF_DATASETS_CACHE = /data/hf_datasets_cache
# datasets.config.HF_DATASETS_CACHE = /data/hf_datasets_cache
# datasets.config.HF_CACHE_HOME = /home/exx/.cache/huggingface

# %%
ds = load_dataset('Idavidrein/gpqa', 'gpqa_main')
