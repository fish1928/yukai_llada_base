# %%
import os
import torch
import numpy as np

import torch.nn.functional as F

from collections import defaultdict
from tqdm import tqdm
from modeling_llada.modeling_llada_with_kv_cache import LLaDAModelLM
from transformers import AutoTokenizer
from datasets import Dataset, load_dataset

from llada_get_loglikelihood import forward_process, get_log_likelihood
from llada_generate import get_num_transfer_tokens, add_gumbel_noise

from jinyu_utils.jinyu_tokenizer import Tokenizer_
from jinyu_utils.jinyu_preprocess_wiki import parse_lines_with_index, merge_subdocs, PATTEN_REG_WIKI
from jinyu_utils.jinyu_dataset import jinyu_load_dataset

# %%
ID_TOKEN_MASK = 126336 # '|mdm_mask|'
ID_TOKEN_PADDING = 126081 # '|endoftext|'
ID_TOKEN_EOT = 126348 # '|eot_id|'

device = 'cuda:1'

id_model = 'GSAI-ML/LLaDA-8B-Base'

# %%
'''load tokenizer'''
tokenizer = AutoTokenizer.from_pretrained(
    id_model,
    # local_files_only=True,
    trust_remote_code=True
)

if tokenizer.padding_side != 'left':
    tokenizer.padding_side = 'left'
# end

assert tokenizer.pad_token_id != 126336

'''load model'''
model_kwargs = {}
model = LLaDAModelLM.from_pretrained(
    id_model,
    trust_remote_code=True,
    torch_dtype=torch.bfloat16,
    **model_kwargs
)

model = model.eval().to(device)
device_for_input = model.get_input_embeddings().weight.device
# Out:
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# Loading checkpoint shards: 100%|██████████| 6/6 [00:00<00:00, 10.65it/s]

# %%
ds = jinyu_load_dataset(1, split='test')['text']

'''preprocess dataset'''
docs, _ = parse_lines_with_index(PATTEN_REG_WIKI, ds)
docs = docs['subdocs']

samples = []
for doc in docs:
    lines_1 = doc['texts']
    paragraph_1 = ' '.join(lines_1)
    lines_remain, titles = merge_subdocs(doc['subdocs'])
    paragraph_remain = ' '.join(lines_remain)
    prefix = paragraph_1
    target = paragraph_remain
    samples.append({'prefix': prefix, 'target': target})
# end


samples = samples[:1]
print(len(samples))


sample = samples[0]
prompt_ = sample['prefix']
target_ = sample['target']

with torch.no_grad():
    inputs_encoded = tokenizer(
        prompt_,
        add_special_tokens=False,
        return_tensors="pt"
    )

    targets_encoded = tokenizer(
        target_,
        add_special_tokens=False,
        return_tensors="pt"
    )

    ids_input = inputs_encoded['input_ids'].to(device_for_input)
    ids_target = targets_encoded['input_ids'].to(device_for_input)
    # generate_with_ppl(model, ids_input, ids_target[:, :128], steps=32, gen_length=128, block_length=32, remasking='confidence_top_k')

# end
# Out:
# 1

# %%
def run(model, ids_input, ids_target, remasking):
    with torch.no_grad():
        model = model
        prompt = ids_input
        target = ids_target[:,:128]
        attention_mask=None
        steps=128
        gen_length=128
        block_length=128
        temperature=0
        remasking=remasking
        mask_id=126336
        logits_eos_inf=False
        confidence_eos_eot_inf=False

        _pairs_log_unmask = []
        
        # (batch, full_length)
        x = torch.full((prompt.shape[0], prompt.shape[1] + gen_length), mask_id, dtype=torch.long).to(model.device)
        x[:, :prompt.shape[1]] = prompt.clone()

        y = torch.full(x.shape, mask_id, dtype=torch.long).to(model.device)
        y[:, -target.shape[-1]:] = target   # expand target into y

        probs_all = torch.zeros(x.shape, dtype=torch.bfloat16).to(model.device)


        # fill prompts

        if attention_mask is not None:
            attention_mask = torch.cat([attention_mask, torch.ones((prompt.shape[0], gen_length), dtype=attention_mask.dtype, device=model.device)], dim=-1)
        # end

        assert gen_length % block_length == 0
        num_blocks = gen_length // block_length

        assert steps % num_blocks == 0
        steps_per_block = steps // num_blocks

        for num_block in range(num_blocks):
            mask_block = (x[:, prompt.shape[1] + num_block*block_length : prompt.shape[1]+(num_block + 1)*block_length]) == mask_id
            nums_transfer_tokens = get_num_transfer_tokens(mask_block, steps_per_block)    # [[7,7,6],..] if steps_per_block = 3 and remainder = 2
            del mask_block

            for step_per_block in range(steps_per_block):   # TODO: 1 -> steps_per_block
            
                logits = model(x, attention_mask=attention_mask, cache_kv=True).logits

                if logits_eos_inf:
                    logits[:, :, ID_TOKEN_PADDING] = -torch.inf
                # end

                logits_with_noise = add_gumbel_noise(logits, temperature=temperature)
                x0 = torch.argmax(logits_with_noise, dim=-1) # b, l -> [[id0_5, id1_3, ...],..] (this is the index of native max)

                if confidence_eos_eot_inf:
                    logits_with_noise[:, :, ID_TOKEN_PADDING] = logits[:, :, ID_TOKEN_EOT] = -torch.inf
                # end

                p = F.softmax(logits, dim=-1)
                del logits

                index_p = None  # we are going to handle the index_p
                match remasking:
                    case 'generate_top_k':
                        index_p = x0.unsqueeze(-1)    # ALERT: original code
                        # index_p = y.unsqueeze(-1)
                    case 'truth_top_k' | 'random_top_k':
                        index_p = y.unsqueeze(-1)
                    case _:
                        raise NotImplementedError(remasking)
                    # end
                # end match
                x0_p = torch.squeeze(p.gather(dim=-1, index=index_p), -1) # b, l [[0.9, 0.7],..]

                # set mask
                mask_current_full = torch.where(x==mask_id, True, False)    # set prompt to False
                mask_current_full[:, (prompt.shape[1]+(num_block+1)*block_length):] = False # set future block to False
                # print((mask_current_full == True).sum())  # DEBUG Random issue here
                # print(x0_p[mask_current_full])

                x0 = torch.where(mask_current_full, x0, x)  # restore non-current-block tokens
                x0_p_current_full = torch.where(mask_current_full, x0_p, -np.inf)

                # update x0, keep x0=x0 for the current & future blocks, override x0=x for prompt
                mask_transfered = torch.zeros_like(x0, dtype=torch.bool, device=x0.device)
                k=nums_transfer_tokens[:, step_per_block]

                if remasking == 'random_top_k':
                    idx_mask_current = mask_current_full.nonzero(as_tuple=True)[-1].reshape(mask_current_full.shape[0], -1) # 1d
                    perm = torch.argsort(torch.rand(idx_mask_current.shape[0], idx_mask_current.shape[1], device=mask_current_full.device), dim=-1)
                    idx_unmask_k = idx_mask_current.gather(-1, perm)[:,:k]
                else:
                    _, idx_unmask_k = torch.topk(x0_p_current_full, k)
                # end if-else

                mask_transfered.scatter_(-1, idx_unmask_k, True)            # VALID format of this mask_transfered[idx_unmask_k] = True

                x[mask_transfered] = y[mask_transfered]                     # original code:   x[mask_transfered] = x0[mask_transfered]
                probs_all[mask_transfered] = x0_p_current_full[mask_transfered]   #
                _pairs_log_unmask.append({
                    'id_token': y[mask_transfered].detach().cpu(),
                    'idx_token': idx_unmask_k.detach().cpu()
                })
                # end
            # end for steps
        # end for blocks
    # end with
    return probs_all, y != mask_id, _pairs_log_unmask
# end

# %%
def calculate_ppl_and_conf(probs_all, mask_target, eps=1e-12):
    probs_collected = probs_all[mask_target].reshape(mask_target.shape[0], -1)  # [B, K]

    # Arithmetic mean confidence (what you currently call mean_prob)
    mean_prob = probs_collected.mean(dim=-1)  # [B]

    # Per-token NLL and per-row PPL (geometric-mean based)
    nll_collected = -torch.log(probs_collected + eps)   # [B, K]
    nll_per = nll_collected.mean(dim=-1)                 # [B]
    ppl_per = torch.exp(nll_per)                        # [B]

    # Geometric mean confidence (this one is directly tied to PPL)
    # geo_prob = torch.exp(torch.log(probs_collected + eps).mean(dim=1))  # [B]
    # And ppl_per == 1 / geo_prob (up to eps effects)

    return ppl_per.item(), mean_prob.item()
# end

# %%
probs_truth, mask_current_full, pairs_log_unmask = run(model, ids_input, ids_target, 'truth_top_k')
# probs_random, mask_current_full = run(model, ids_input, ids_target, 'random_top_k')
print(calculate_ppl_and_conf(probs_truth, mask_current_full))
# print(calculate_ppl_and_conf(probs_random, mask_current_full))
# Out:
# (3.203125, 0.56640625)

# %%
pairs_log_unmask
# model.model.transformer.blocks[-1]._k_previous.shape
# Out:
# [{'id_token': tensor([268]), 'idx_token': tensor([[470]])},
#  {'id_token': tensor([4297]), 'idx_token': tensor([[472]])},
#  {'id_token': tensor([13942]), 'idx_token': tensor([[471]])},
#  {'id_token': tensor([366]), 'idx_token': tensor([[469]])},
#  {'id_token': tensor([4307]), 'idx_token': tensor([[468]])},
#  {'id_token': tensor([45653]), 'idx_token': tensor([[467]])},
#  {'id_token': tensor([13808]), 'idx_token': tensor([[463]])},
#  {'id_token': tensor([12]), 'idx_token': tensor([[465]])},
#  {'id_token': tensor([1192]), 'idx_token': tensor([[464]])},
#  {'id_token': tensor([31]), 'idx_token': tensor([[466]])},
#  {'id_token': tensor([259]), 'idx_token': tensor([[462]])},
#  {'id_token': tensor([1028]), 'idx_token': tensor([[461]])},
#  {'id_token': tensor([10877]), 'idx_token': tensor([[474]])},
#  {'id_token': tensor([468]), 'idx_token': tensor([[473]])},
#  {'id_token': tensor([477]), 'idx_token': tensor([[547]])},
#  {'id_token': tensor([373]), 'idx_token': tensor([[435]])},
#  {'id_token': tensor([28]), 'idx_token': tensor([[430]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[457]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[456]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[455]])},
#  {'id_token': tensor([17]), 'idx_token': tensor([[454]])},
#  {'id_token': tensor([220]), 'idx_token': tensor([[453]])},
#  {'id_token': tensor([413]), 'idx_token': tensor([[458]])},
#  {'id_token': tensor([7510]), 'idx_token': tensor([[459]])},
#  {'id_token': tensor([390]), 'idx_token': tensor([[460]])},
#  {'id_token': tensor([718]), 'idx_token': tensor([[452]])},
#  {'id_token': tensor([296]), 'idx_token': tensor([[483]])},
#  {'id_token': tensor([268]), 'idx_token': tensor([[484]])},
#  {'id_token': tensor([477]), 'idx_token': tensor([[543]])},
#  {'id_token': tensor([268]), 'idx_token': tensor([[549]])},
#  {'id_token': tensor([1250]), 'idx_token': tensor([[492]])},
#  {'id_token': tensor([390]), 'idx_token': tensor([[531]])},
#  {'id_token': tensor([7510]), 'idx_token': tensor([[530]])},
#  {'id_token': tensor([413]), 'idx_token': tensor([[529]])},
#  {'id_token': tensor([296]), 'idx_token': tensor([[514]])},
#  {'id_token': tensor([220]), 'idx_token': tensor([[515]])},
#  {'id_token': tensor([17]), 'idx_token': tensor([[516]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[517]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[518]])},
#  {'id_token': tensor([16]), 'idx_token': tensor([[519]])},
#  {'id_token': tensor([296]), 'idx_token': tensor([[548]])},
#  {'id_token': tensor([12422]), 'idx_token': tensor([[485]])},
#  {'id_token': tensor([477]), 'idx_token': tensor([[491]])},
#  {'id_token': tensor([477]), 'idx_token': tensor([[482]])},
#  {'id_token': tensor([15542]), 'idx_token': tensor([[522]])},
#  {'id_token': tensor([482]), 'idx_token': tensor([[520]])},
#  {'id_token': tensor([268]), 'idx_token': tensor([[521]])},
#  {'id_token': tensor([21697]), 'idx_token': tensor([[524]])},
#  {'id_token': tensor([5632]), 'idx_token': tensor([[523]])},
#  {'id_token': tensor([7249]), 'idx_token': tensor([[513]])},
#  {'id_token': tensor([529]), 'idx_token': tensor([[512]])},
#  {'id_token': tensor([818]), 'idx_token': tensor([[511]])},
#  {'id_token': tensor([2347]), 'idx_token': tensor([[510]])},
#  {'id_token': tensor([82902]), 'idx_token': tensor([[509]])},
#  {'id_token': tensor([23450]), 'idx_token': tensor([[508]])},
#  {'id_token': tensor([527]), 'idx_token': tensor([[507]])},
#  {'id_token': tensor([5243]), 'idx_token': tensor([[506]])},
#  {'id_token': tensor([1250]), 'idx_token': tensor([[525]])},
#  {'id_token': tensor([6617]), 'idx_token': tensor([[504]])},
#  {'id_token': tensor([1124]), 'idx_token': tensor([[505]])},
#  {'id_token': tensor([1569]), 'idx_token': tensor([[503]])},
#  {'id_token': tensor([296]), 'idx_token': tensor([[501]])},
#  {'id_token': tensor([268]), 'idx_token': tensor([[502]])},
#  {'id_token': tensor([409]), 'idx_token': tensor([[542]])},
#  {'id_token': tensor([477]), 'idx_token': tensor([[478]])},
#  {'id_token': tensor([477]), 'idx_token': tensor([[487]])},
#  {'id_token': tensor([2347]), 'idx_token': tensor([[486]])},
#  {'id_token': tensor([2347]), 'idx_token': tensor([[551]])},
#  {'id_token': tensor([413]), 'idx_token': tensor([[493]])},
#  {'id_token': tensor([7510]), 'idx_token': tensor([[494]])},
#  {'id_token': tensor([390]), 'idx_token': tensor([[495]])},
#  {'id_token': tensor([464]), 'idx_token': tensor([[476]])},
#  {'id_token': tensor([5947]), 'idx_token': tensor([[475]])},
#  {'id_token': tensor([50915]), 'idx_token': tensor([[477]])},
#  {'id_token': tensor([373]), 'idx_token': tensor([[451]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[440]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[441]])},
#  {'id_token': tensor([373]), 'idx_token': tensor([[436]])},
#  {'id_token': tensor([373]), 'idx_token': tensor([[450]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[447]])},
#  {'id_token': tensor([373]), 'idx_token': tensor([[431]])},
#  {'id_token': tensor([373]), 'idx_token': tensor([[434]])},
#  {'id_token': tensor([373]), 'idx_token': tensor([[449]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[446]])},
#  {'id_token': tensor([17]), 'idx_token': tensor([[445]])},
#  {'id_token': tensor([220]), 'idx_token': tensor([[444]])},
#  {'id_token': tensor([15]), 'idx_token': tensor([[442]])},
#  {'id_token': tensor([17]), 'idx_token': tensor([[439]])},
#  {'id_token': tensor([220]), 'idx_token': tensor([[438]])},
#  {'id_token': tensor([373]), 'idx_token': tensor([[437]])},
#  {'id_token': tensor([373]), 'idx_token': tensor([[433]])},
#  {'id_token': tensor([28782]), 'idx_token': tensor([[432]])},
#  {'id_token': tensor([20]), 'idx_token': tensor([[448]])},
#  {'id_token': tensor([64435]), 'idx_token': tensor([[496]])},
#  {'id_token': tensor([409]), 'idx_token': tensor([[497]])},
#  {'id_token': tensor([477]), 'idx_token': tensor([[500]])},
#  {'id_token': tensor([477]), 'idx_token': tensor([[498]])},
#  {'id_token': tensor([296]), 'idx_token': tensor([[535]])},
#  {'id_token': tensor([468]), 'idx_token': tensor([[536]])},
#  {'id_token': tensor([689]), 'idx_token': tensor([[532]])},
#  {'id_token': tensor([82]), 'idx_token': tensor([[533]])},
#  {'id_token': tensor([4178]), 'idx_token': tensor([[534]])},
#  {'id_token': tensor([300]), 'idx_token': tensor([[528]])},
#  {'id_token': tensor([355]), 'idx_token': tensor([[526]])},
#  {'id_token': tensor([3042]), 'idx_token': tensor([[527]])},
#  {'id_token': tensor([1653]), 'idx_token': tensor([[541]])},
#  {'id_token': tensor([6569]), 'idx_token': tensor([[540]])},
#  {'id_token': tensor([301]), 'idx_token': tensor([[552]])},
#  {'id_token': tensor([4307]), 'idx_token': tensor([[550]])},
#  {'id_token': tensor([366]), 'idx_token': tensor([[538]])},
#  {'id_token': tensor([8382]), 'idx_token': tensor([[539]])},
#  {'id_token': tensor([29323]), 'idx_token': tensor([[537]])},
#  {'id_token': tensor([464]), 'idx_token': tensor([[553]])},
#  {'id_token': tensor([4754]), 'idx_token': tensor([[554]])},
#  {'id_token': tensor([7708]), 'idx_token': tensor([[556]])},
#  {'id_token': tensor([296]), 'idx_token': tensor([[557]])},
#  {'id_token': tensor([718]), 'idx_token': tensor([[488]])},
#  {'id_token': tensor([47539]), 'idx_token': tensor([[490]])},
#  {'id_token': tensor([25518]), 'idx_token': tensor([[489]])},
#  {'id_token': tensor([1219]), 'idx_token': tensor([[443]])},
#  {'id_token': tensor([7374]), 'idx_token': tensor([[555]])},
#  {'id_token': tensor([11701]), 'idx_token': tensor([[479]])},
#  {'id_token': tensor([759]), 'idx_token': tensor([[481]])},
#  {'id_token': tensor([5119]), 'idx_token': tensor([[480]])},
#  {'id_token': tensor([11701]), 'idx_token': tensor([[499]])},
#  {'id_token': tensor([7427]), 'idx_token': tensor([[546]])},
#  {'id_token': tensor([3484]), 'idx_token': tensor([[545]])},
#  {'id_token': tensor([99086]), 'idx_token': tensor([[544]])}]
